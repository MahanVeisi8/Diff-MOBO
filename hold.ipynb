# %%
import numpy as np
import torch
import os,sys

# %%
file_results = np.load("run_results_xstrain_final.npy",allow_pickle=True).item()
xs_train = np.load(rf"data/xs_train.npy",allow_pickle=True)

# %%
file_shapes = file_results["shapes"]
file_performances = file_results["performances"]

# %%
indices = []
for s in xs_train:
    for i in range(len(file_shapes)):
        shape = file_shapes[i]
        performances = file_performances[i]
        if performances[0] == -1000:
            continue
        if np.array_equal(shape, s):
            indices.append(i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       6 if performances[0] == -1000:
#       7     continue
# ----> 8 if np.array_equal(shape, s):
#       9     indices.append(i)
#
# File <__array_function__ internals>:200, in array_equal(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/numeric.py:2468, in array_equal(a1, a2, equal_nan)
#    2466     return False
#    2467 if not equal_nan:
# -> 2468     return bool(asarray(a1 == a2).all())
#    2469 # Handling NaN values if equal_nan is True
#    2470 a1nan, a2nan = isnan(a1), isnan(a2)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/_methods.py:64, in _all(a, axis, dtype, out, keepdims, where)
#      61 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      62     # Parsing keyword arguments is currently fairly slow, so avoid it for now
# ...

# %%
indices =[]
for i in range(len(file_performances)):
    if file_performances[i][0]== -1000:
        continue
    else:
        indices.append(i)

# %%
len(indices) ,len(xs_train)
# Out:
# (38746, 38802)

# %%
valid_shapes = file_shapes[indices]
valid_performances = file_performances[indices][:,:2]
valid_shapes.shape , valid_performances.shape
# Out:
# ((38746, 192, 2), (38746, 2))

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Assuming you already have:
# valid_shapes = np.load('valid_shapes.npy')
# valid_performances = np.load('valid_performances.npy')

# Choose test size (e.g., 3000 samples)
# test_size = 3000 / len(valid_shapes)  # proportional split

# Split the data
shapes_train, shapes_test, perf_train, perf_test = train_test_split(
    valid_shapes,
    valid_performances,
    test_size=0.1,
    random_state=42,
    shuffle=True
)

# Optionally save the splits
np.save('xs_train_MPI.npy', shapes_train)
np.save('xs_test_MPI.npy', shapes_test)
np.save('ys_train_MPI.npy', perf_train)
np.save('ys_test_MPI.npy', perf_test)

print(f"Train set: {len(shapes_train)} samples")
print(f"Test set: {len(shapes_test)} samples")
# Out:
# Train set: 34871 samples
# Test set: 3875 samples

# %%
label_coord_min_max = np.load(rf"data/label_min_max.npy",allow_pickle=True)

# %%
label_coord_min_max
# Out:
# array([[0., 0.],
#        [1., 1.]], dtype=float32)

# %%
coord_min_max = np.load(rf"data/coord_min_max.npy",allow_pickle=True)
coord_min_max
# Out:
# array([[0., 0.],
#        [1., 1.]], dtype=float32)
